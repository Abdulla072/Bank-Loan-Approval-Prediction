# %%
import sys

print(sys.executable)
# Out:
# d:\Projects\Bank-Loan-Approval-Prediction\bank_loan_approval_env\Scripts\python.exe

# %%
import os
import sys

project_root = os.path.abspath("..")
src_path = os.path.join(project_root, "src")

if src_path not in sys.path:
    sys.path.insert(0, src_path)

print(src_path)
# Out:
# d:\Projects\Bank-Loan-Approval-Prediction\src

# %%
from loan_approval.utils.common import read_yaml

schema = read_yaml("../config/schema.yaml")

print(schema)
# Out:
# {'columns': {'loan_id': 'int64', 'no_of_dependents': 'int64', 'education': 'object', 'self_employed': 'object', 'income_annum': 'int64', 'loan_amount': 'int64', 'loan_term': 'int64', 'cibil_score': 'int64', 'residential_assets_value': 'int64', 'commercial_assets_value': 'int64', 'luxury_assets_value': 'int64', 'bank_asset_value': 'int64', 'loan_status': 'object'}}

# %%
import os
import sys

print(os.getcwd())
print(sys.path[:3])
# Out:
# d:\Projects\Bank-Loan-Approval-Prediction\notebooks
# ['C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python311\\Lib']

# %%
from loan_approval.utils.common import read_yaml

schema = read_yaml("config/schema.yaml")

print(schema)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from loan_approval.utils.common import read_yaml
#       2
#       3 schema = read_yaml("config/schema.yaml")
#       4
#
# ModuleNotFoundError: No module named 'loan_approval'

# %%
import sys

print(sys.executable)
# Out:
# d:\Projects\Bank-Loan-Approval-Prediction\.venv\Scripts\python.exe

# %%
from loan_approval.utils.common import read_yaml

schema = read_yaml("../config/schema.yaml")

print(schema)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from loan_approval.utils.common import read_yaml
#       2
#       3 schema = read_yaml("../config/schema.yaml")
#       4
#
# ModuleNotFoundError: No module named 'loan_approval'
